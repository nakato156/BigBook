# %%
from pathlib import Path
import pandas as pd
import sys

PROJECT_ROOT = Path.cwd().parents[1] if Path.cwd().name == "reduction" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.reduction.feature_matrix import generate_feature_matrices, manifest_summary

# %% [markdown]
# # Feature Matrix

# %%
manifest = generate_feature_matrices()
summary = manifest_summary(manifest)
summary
# Out:
#                  category     status  book_rows  interaction_rows  \
# 0      fantasy_paranormal  generated      31281          21575033
# 1       history_biography  generated      23360           7162251
# 2  mystery_thriller_crime  generated      23644           7525320
# 3                 romance  generated      40530          13963228
# 4             young_adult  generated      12314          11726378
#
#                                        processed_dir
# 0  /home/nakato/projects/BigBook/data/processed/f...
# 1  /home/nakato/projects/BigBook/data/processed/h...
# 2  /home/nakato/projects/BigBook/data/processed/m...
# 3  /home/nakato/projects/BigBook/data/processed/r...
# 4  /home/nakato/projects/BigBook/data/processed/y...

# %%
manifest
# Out:
# {'generated_categories': [{'category': 'fantasy_paranormal',
#    'processed_dir': '/home/nakato/projects/BigBook/data/processed/fantasy_paranormal',
#    'book_features': '/home/nakato/projects/BigBook/data/features/fantasy_paranormal/book_features.parquet',
#    'interaction_features': '/home/nakato/projects/BigBook/data/features/fantasy_paranormal/interaction_features.parquet',
#    'book_rows': 31281,
#    'interaction_rows': 21575033},
#   {'category': 'history_biography',
#    'processed_dir': '/home/nakato/projects/BigBook/data/processed/history_biography',
#    'book_features': '/home/nakato/projects/BigBook/data/features/history_biography/book_features.parquet',
#    'interaction_features': '/home/nakato/projects/BigBook/data/features/history_biography/interaction_features.parquet',
#    'book_rows': 23360,
#    'interaction_rows': 7162251},
#   {'category': 'mystery_thriller_crime',
#    'processed_dir': '/home/nakato/projects/BigBook/data/processed/mystery_thriller_crime',
#    'book_features': '/home/nakato/projects/BigBook/data/features/mystery_thriller_crime/book_features.parquet',
#    'interaction_features': '/home/nakato/projects/BigBook/data/features/mystery_thriller_crime/interaction_features.parquet',
#    'book_rows': 23644,
#    'interaction_rows': 7525320},
#   {'category': 'romance',
#    'processed_dir': '/home/nakato/projects/BigBook/data/processed/romance',
#    'book_features': '/home/nakato/projects/BigBook/data/features/romance/book_features.parquet',
#    'interaction_features': '/home/nakato/projects/BigBook/data/features/romance/interaction_features.parquet',
#    'book_rows': 40530,
#    'interaction_rows': 13963228},
#   {'category': 'young_adult',
#    'processed_dir': '/home/nakato/projects/BigBook/data/processed/young_adult',
#    'book_features': '/home/nakato/projects/BigBook/data/features/young_adult/book_features.parquet',
#    'interaction_features': '/home/nakato/projects/BigBook/data/features/young_adult/interaction_features.parquet',
#    'book_rows': 12314,
#    'interaction_rows': 11726378}],
#  'missing_categories': [],
#  'user_features_global': '/home/nakato/projects/BigBook/data/features/user_features_global.parquet',
#  'user_rows': 555472}

# %% [markdown]
# ## Inspect generated matrices

# %%
FEATURES_PATH = PROJECT_ROOT / "data" / "features"

# Example: inspect the Fantasy & Paranormal book feature matrix when available.
fantasy_book_features_path = FEATURES_PATH / "fantasy_paranormal" / "book_features.parquet"
if fantasy_book_features_path.exists():
    df_fantasy = pd.read_parquet(fantasy_book_features_path)
    display(df_fantasy.head())
    display(df_fantasy.isna().sum().sort_values(ascending=False).head(10))
# Out:
#              category   book_id  \
# 0  fantasy_paranormal  13519484
# 1  fantasy_paranormal   2741850
# 2  fantasy_paranormal  18663972
# 3  fantasy_paranormal  10806008
# 4  fantasy_paranormal  11731782
#
#                                                title  \
# 0                  Wolf Pact, Part I (Wolf Pact, #1)
# 1        Personal Demon (Women of the Otherworld #8)
# 2                       Fortune's Pawn (Paradox, #1)
# 3  Peter Nimble and His Fantastic Eyes (Peter Nim...
# 4                              Collide (Collide, #1)
#
#                                          description  average_rating  \
# 0  The ancient wolves were once proud guardians o...            3.91
# 1  In her acclaimed Women of the Otherworld serie...            4.07
# 2  When professional mercenary Deviana Morris too...            3.96
# 3  Peter Nimble and His Fantastic Eyesis the utte...            4.04
# 4  Sherry has always known there was something ou...            3.86
#
#    ratings_count_p99  text_reviews_count_p99  num_pages_p99  \
# 0              462.0                    24.0           57.0
# 1              385.0                    39.0          523.0
# 2             1023.0                    86.0          340.0
# 3             6049.0                   890.0          400.0
# 4             5125.0                   346.0          360.0
#
#    publication_year_clean  is_ebook  ... is_cold_start  \
# 0                  2012.0      True  ...          None
# 1                  2008.0     False  ...          None
# 2                     NaN      True  ...          None
# 3                  2011.0     False  ...          None
# 4                  2011.0      True  ...          None
#
#   theme_epic_high_fantasy theme_urban_paranormal theme_science_fiction  \
# 0                   False                   True                 False
# 1                   False                   True                  True
# 2                   False                   True                  True
# 3                   False                  False                  True
# 4                   False                   True                  True
#
#    theme_magic_wizards  theme_creatures_mythology  theme_romance_fantasy  \
# 0                 True                       True                   True
# 1                 True                       True                   True
# 2                False                      False                  False
# 3                 True                      False                  False
# 4                False                      False                   True
#
#   theme_young_adult  theme_general_fantasy  fantasy_theme_count
# 0              True                   True                    6
# 1             False                   True                    6
# 2              True                   True                    4
# 3              True                   True                    4
# 4              True                   True                    5
#
# [5 rows x 31 columns]
# top_shelf                  31281
# is_cold_start              31281
# primary_author_id          31281
# publisher                   7331
# format                      7257
# publication_year_clean      5668
# num_pages_p99               4767
# description                 1305
# to_read_count                138
# theme_epic_high_fantasy        0
# dtype: int64

# %%
user_features_path = FEATURES_PATH / "user_features_global.parquet"
if user_features_path.exists():
    user_features_global = pd.read_parquet(user_features_path)
    display(user_features_global.head())
    display(user_features_global.shape)
# Out:
#                             user_id  interaction_count  rated_count  \
# 0  00000377eea48021d3002730d56aca9a                 45           45
# 1  00004584d524ec468619e81b176cc991                 79           79
# 2  000079c580bbe45e1500acabe551b276                 12           12
# 3  00009ab2ed8cbfceda5a59da40966321                 76           76
# 4  00009e46d18f223a82b22da38586b605                119          119
#
#    review_count  read_count  shelf_only_count  mean_rating  rating_std  \
# 0             1          45                 0     4.355556    0.908434
# 1             0          79                 0     4.139241    0.674331
# 2             0          12                 0     3.333333    0.984732
# 3             0          76                 0     4.381579    0.515548
# 4            68         119                 0     3.285714    0.738102
#
#    user_rating_bias  avg_reading_duration_days  has_reading_duration_rate  \
# 0          0.376897                  32.521739                   0.511111
# 1          0.160582                  21.500000                   0.025316
# 2         -0.645325                   1.000000                   0.166667
# 3          0.402920                  29.500000                   0.026316
# 4         -0.692944                  21.390244                   0.689076
#
#    category_count                                         categories
# 0               2                     fantasy_paranormal|young_adult
# 1               3             fantasy_paranormal|romance|young_adult
# 2               1                                  history_biography
# 3               1                                 fantasy_paranormal
# 4               4  fantasy_paranormal|history_biography|mystery_t...
# (555472, 13)
