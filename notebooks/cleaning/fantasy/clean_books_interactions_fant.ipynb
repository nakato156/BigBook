# %%
from pathlib import Path
import os
import sys

import numpy as np
import pandas as pd
import pyarrow.parquet as pq
from IPython.display import display

PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / 'src').exists() and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent

os.chdir(PROJECT_ROOT)
sys.path.insert(0, str(PROJECT_ROOT))

from src.config import CATEGORIES
from src.utils.io import read_jsonl_sample

CATEGORY = 'fantasy_paranormal'
cfg = CATEGORIES[CATEGORY]
OUTPUT_DIR = cfg.interim_dir
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(f'Category: {cfg.display_name}')
print(f'Books file: {cfg.books_file}')
print(f'Interactions file: {cfg.interactions_file}')
print(f'Output dir: {OUTPUT_DIR}')
# Out:
# Category: Fantasy & Paranormal
# Books file: /home/nakato/projects/BigBook/data/raw/goodreads_books_fantasy_paranormal.json.gz
# Interactions file: /home/nakato/projects/BigBook/data/raw/goodreads_interactions_fantasy_paranormal.json.gz
# Output dir: /home/nakato/projects/BigBook/data/interim/fantasy_paranormal

# %% [markdown]
# ---
# # Books

# %%
SAMPLE_SIZE = 5_000
books_sample = read_jsonl_sample(cfg.books_file, nrows=SAMPLE_SIZE)
print(f'Shape: {books_sample.shape}')
print(f'Columns ({len(books_sample.columns)}):')
print(list(books_sample.columns))
# Out:
# Shape: (5000, 29)
# Columns (29):
# ['isbn', 'text_reviews_count', 'series', 'country_code', 'language_code', 'popular_shelves', 'asin', 'is_ebook', 'average_rating', 'kindle_asin', 'similar_books', 'description', 'format', 'link', 'authors', 'publisher', 'num_pages', 'publication_day', 'isbn13', 'publication_month', 'edition_information', 'publication_year', 'url', 'image_url', 'book_id', 'ratings_count', 'work_id', 'title', 'title_without_series']

# %%
summary_books = pd.DataFrame({
    'dtype': books_sample.dtypes.astype(str),
    'non_null': books_sample.notna().sum(),
    'null_count': books_sample.isna().sum(),
    'null_pct': (books_sample.isna().sum() / len(books_sample) * 100).round(1),
    'n_unique': books_sample.apply(lambda col: col.map(str).nunique()),
    'example': books_sample.iloc[0].astype(str).str[:80],
})
display(summary_books)
# Out:
#                        dtype  non_null  null_count  null_pct  n_unique  \
# isbn                     str      5000           0       0.0      2527
# text_reviews_count       str      5000           0       0.0       305
# series                object      5000           0       0.0      3328
# country_code             str      5000           0       0.0         1
# language_code            str      5000           0       0.0        44
# popular_shelves       object      5000           0       0.0      4655
# asin                     str      5000           0       0.0      1322
# is_ebook                 str      5000           0       0.0         2
# average_rating           str      5000           0       0.0       212
# kindle_asin              str      5000           0       0.0      2346
# similar_books         object      5000           0       0.0      3237
# description              str      5000           0       0.0      4549
# format                   str      5000           0       0.0        42
# link                     str      5000           0       0.0      5000
# authors               object      5000           0       0.0      3833
# publisher                str      5000           0       0.0      1949
# num_pages                str      5000           0       0.0       686
# publication_day          str      5000           0       0.0        32
# isbn13                   str      5000           0       0.0      3124
# publication_month        str      5000           0       0.0        13
# edition_information      str      5000           0       0.0       260
# publication_year         str      5000           0       0.0        73
# url                      str      5000           0       0.0      5000
# image_url                str      5000           0       0.0      3361
# book_id                  str      5000           0       0.0      5000
# ratings_count            str      5000           0       0.0       938
# work_id                  str      5000           0       0.0      4625
# title                    str      5000           0       0.0      4881
# title_without_series     str      5000           0       0.0      4881
#
#                                                                 example
# isbn
# text_reviews_count                                                    7
# series                                                       ['189911']
# country_code                                                         US
# language_code                                                       eng
# popular_shelves       [{'count': '58', 'name': 'to-read'}, {'count':...
# asin                                                         B00071IKUY
# is_ebook                                                          false
# average_rating                                                     4.03
# kindle_asin
# similar_books         ['19997', '828466', '1569323', '425389', '1176...
# description           Omnibus book club edition containing the Ladie...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/7327624-th...
# authors                            [{'author_id': '10333', 'role': ''}]
# publisher                                        Nelson Doubleday, Inc.
# num_pages                                                           600
# publication_day
# isbn13
# publication_month
# edition_information                                   Book Club Edition
# publication_year                                                   1987
# url                   https://www.goodreads.com/book/show/7327624-th...
# image_url             https://images.gr-assets.com/books/1304100136m...
# book_id                                                         7327624
# ratings_count                                                       140
# work_id                                                         8948723
# title                 The Unschooled Wizard (Sun Wolf and Starhawk, ...
# title_without_series  The Unschooled Wizard (Sun Wolf and Starhawk, ...

# %%
books_sample.head(3)
# Out:
#          isbn text_reviews_count     series country_code language_code  \
# 0                              7   [189911]           US           eng
# 1  1934876569                  6   [151854]           US
# 2                             60  [1052227]           US           eng
#
#                                      popular_shelves        asin is_ebook  \
# 0  [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY    false
# 1  [{'count': '515', 'name': 'to-read'}, {'count'...                false
# 2  [{'count': '54', 'name': 'currently-reading'},...  B01NCIKAQX     true
#
#   average_rating kindle_asin  ... publication_month edition_information  \
# 0           4.03              ...                     Book Club Edition
# 1           4.22              ...                 3
# 2           4.33  B01NCIKAQX  ...
#
#   publication_year                                                url  \
# 0             1987  https://www.goodreads.com/book/show/7327624-th...
# 1             2009  https://www.goodreads.com/book/show/6066812-al...
# 2                   https://www.goodreads.com/book/show/33394837-t...
#
#                                            image_url   book_id ratings_count  \
# 0  https://images.gr-assets.com/books/1304100136m...   7327624           140
# 1  https://images.gr-assets.com/books/1316637798m...   6066812            98
# 2  https://images.gr-assets.com/books/1493114742m...  33394837           269
#
#     work_id                                              title  \
# 0   8948723  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 1    701117  All's Fairy in Love and War (Avalon: Web of Ma...
# 2  54143148            The House of Memory (Pluto's Snitch #2)
#
#                                 title_without_series
# 0  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 1  All's Fairy in Love and War (Avalon: Web of Ma...
# 2            The House of Memory (Pluto's Snitch #2)
#
# [3 rows x 29 columns]

# %%
BOOKS_COLUMNS_TO_DROP = [
    'isbn',
    'isbn13',
    'asin',
    'kindle_asin',
    'url',
    'link',
    'image_url',
    'country_code',
    'edition_information',
    'publication_day',
    'publication_month',
    'similar_books',
    'title_without_series',
]

# %%
books_clean = books_sample.drop(columns=[c for c in BOOKS_COLUMNS_TO_DROP if c in books_sample.columns])

# %%
summary_clean = pd.DataFrame({
    'dtype': books_clean.dtypes.astype(str),
    'non_null': books_clean.notna().sum(),
    'null_pct': (books_clean.isna().sum() / len(books_clean) * 100).round(1),
})
display(summary_clean)
# Out:
#                      dtype  non_null  null_pct
# text_reviews_count     str      5000       0.0
# series              object      5000       0.0
# language_code          str      5000       0.0
# popular_shelves     object      5000       0.0
# is_ebook               str      5000       0.0
# average_rating         str      5000       0.0
# description            str      5000       0.0
# format                 str      5000       0.0
# authors             object      5000       0.0
# publisher              str      5000       0.0
# num_pages              str      5000       0.0
# publication_year       str      5000       0.0
# book_id                str      5000       0.0
# ratings_count          str      5000       0.0
# work_id                str      5000       0.0
# title                  str      5000       0.0

# %%
books_clean.head(5)
# Out:
#   text_reviews_count     series language_code  \
# 0                  7   [189911]           eng
# 1                  6   [151854]
# 2                 60  [1052227]           eng
# 3                  1   [147734]
# 4                 21   [811663]         en-US
#
#                                      popular_shelves is_ebook average_rating  \
# 0  [{'count': '58', 'name': 'to-read'}, {'count':...    false           4.03
# 1  [{'count': '515', 'name': 'to-read'}, {'count'...    false           4.22
# 2  [{'count': '54', 'name': 'currently-reading'},...     true           4.33
# 3  [{'count': '1057', 'name': 'to-read'}, {'count...     true           4.04
# 4  [{'count': '598', 'name': 'to-read'}, {'count'...     true           4.23
#
#                                          description     format  \
# 0  Omnibus book club edition containing the Ladie...  Hardcover
# 1  To Kara's astonishment, she discovers that a p...  Paperback
# 2
# 3  This is the final tale in the bestselling auth...
# 4
#
#                                              authors               publisher  \
# 0               [{'author_id': '10333', 'role': ''}]  Nelson Doubleday, Inc.
# 1               [{'author_id': '19158', 'role': ''}]              Seven Seas
# 2              [{'author_id': '242185', 'role': ''}]
# 3  [{'author_id': '50873', 'role': ''}, {'author_...
# 4             [{'author_id': '5360266', 'role': ''}]
#
#   num_pages publication_year   book_id ratings_count   work_id  \
# 0       600             1987   7327624           140   8948723
# 1       216             2009   6066812            98    701117
# 2       318                   33394837           269  54143148
# 3                             12182387             4    285263
# 4                             29074693           149  46079519
#
#                                                title
# 0  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 1  All's Fairy in Love and War (Avalon: Web of Ma...
# 2            The House of Memory (Pluto's Snitch #2)
# 3                     The Passion (Dark Visions, #3)
# 4              Prowled Darkness (Dante's Circle, #7)

# %%
from src.utils.io import read_jsonl_chunks
import pyarrow as pa
import pyarrow.parquet as pq

BOOKS_OUTPUT_PATH = OUTPUT_DIR / 'books_clean.parquet'
CHUNKSIZE = 50_000

writer = None
total_rows = 0

for chunk_idx, chunk in enumerate(read_jsonl_chunks(cfg.books_file, chunksize=CHUNKSIZE)):
    chunk = chunk.drop(columns=[c for c in BOOKS_COLUMNS_TO_DROP if c in chunk.columns])
    total_rows += len(chunk)
    
    table = pa.Table.from_pandas(chunk, preserve_index=False)
    if writer is None:
        writer = pq.ParquetWriter(BOOKS_OUTPUT_PATH, table.schema, compression='snappy')
    writer.write_table(table)
    print(f'  Chunk {chunk_idx}: {len(chunk):,} rows (total: {total_rows:,})')

if writer:
    writer.close()
# Out:
#   Chunk 0: 50,000 rows (total: 50,000)
#   Chunk 1: 50,000 rows (total: 100,000)
#   Chunk 2: 50,000 rows (total: 150,000)
#   Chunk 3: 50,000 rows (total: 200,000)
#   Chunk 4: 50,000 rows (total: 250,000)
#   Chunk 5: 8,585 rows (total: 258,585)

# %%
metadata = pq.read_metadata(BOOKS_OUTPUT_PATH)
print(f'Rows parquet: {metadata.num_rows:,}')
print(f'Columns: {metadata.num_columns}')
print(f'File size: {BOOKS_OUTPUT_PATH.stat().st_size / 1e6:.1f} MB')

df_check = pd.read_parquet(BOOKS_OUTPUT_PATH, columns=None).head(3)
print(f'\nFinal columns ({len(df_check.columns)}):')
print(list(df_check.columns))
display(df_check)
# Out:
# Rows parquet: 258,585
# Columns: 18
# File size: 312.4 MB
#
# Final columns (16):
# ['text_reviews_count', 'series', 'language_code', 'popular_shelves', 'is_ebook', 'average_rating', 'description', 'format', 'authors', 'publisher', 'num_pages', 'publication_year', 'book_id', 'ratings_count', 'work_id', 'title']
#    text_reviews_count     series language_code  \
# 0                   7   [189911]           eng
# 1                   6   [151854]
# 2                  60  [1052227]           eng
#
#                                      popular_shelves is_ebook  average_rating  \
# 0  [{'count': '58', 'name': 'to-read'}, {'count':...    false            4.03
# 1  [{'count': '515', 'name': 'to-read'}, {'count'...    false            4.22
# 2  [{'count': '54', 'name': 'currently-reading'},...     true            4.33
#
#                                          description     format  \
# 0  Omnibus book club edition containing the Ladie...  Hardcover
# 1  To Kara's astonishment, she discovers that a p...  Paperback
# 2
#
#                                  authors               publisher num_pages  \
# 0   [{'author_id': '10333', 'role': ''}]  Nelson Doubleday, Inc.       600
# 1   [{'author_id': '19158', 'role': ''}]              Seven Seas       216
# 2  [{'author_id': '242185', 'role': ''}]                               318
#
#   publication_year   book_id  ratings_count   work_id  \
# 0             1987   7327624            140   8948723
# 1             2009   6066812             98    701117
# 2                   33394837            269  54143148
#
#                                                title
# 0  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 1  All's Fairy in Love and War (Avalon: Web of Ma...
# 2            The House of Memory (Pluto's Snitch #2)

# %% [markdown]
# # Interactions

# %%
INTER_SAMPLE_SIZE = 10_000
inter_sample = read_jsonl_sample(cfg.interactions_file, nrows=INTER_SAMPLE_SIZE)
print(f'Shape: {inter_sample.shape}')
print(f'Columns ({len(inter_sample.columns)}):')
print(list(inter_sample.columns))
# Out:
# Shape: (10000, 10)
# Columns (10):
# ['user_id', 'book_id', 'review_id', 'is_read', 'rating', 'review_text_incomplete', 'date_added', 'date_updated', 'read_at', 'started_at']

# %%
summary_inter = pd.DataFrame({
    'dtype': inter_sample.dtypes.astype(str),
    'non_null': inter_sample.notna().sum(),
    'null_count': inter_sample.isna().sum(),
    'null_pct': (inter_sample.isna().sum() / len(inter_sample) * 100).round(1),
    'n_unique': inter_sample.apply(lambda col: col.map(str).nunique()),
    'example': inter_sample.iloc[0].astype(str).str[:80],
})
display(summary_inter)
# Out:
#                         dtype  non_null  null_count  null_pct  n_unique  \
# user_id                   str     10000           0       0.0        91
# book_id                   str     10000           0       0.0      6599
# review_id                 str     10000           0       0.0     10000
# is_read                  bool     10000           0       0.0         2
# rating                  int64     10000           0       0.0         6
# review_text_incomplete    str     10000           0       0.0       497
# date_added                str     10000           0       0.0      9519
# date_updated              str     10000           0       0.0      9472
# read_at                   str     10000           0       0.0      1457
# started_at                str     10000           0       0.0      1222
#
#                                                  example
# user_id                 8842281e1d1347389f2ab93d60773d4d
# book_id                                         19161852
# review_id               4443cb6883624c3772625ef5b7b4e138
# is_read                                            False
# rating                                                 0
# review_text_incomplete
# date_added                Fri Sep 08 10:44:24 -0700 2017
# date_updated              Fri Sep 08 10:44:24 -0700 2017
# read_at
# started_at

# %%
inter_sample.head(3)
# Out:
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d  19161852
# 1  8842281e1d1347389f2ab93d60773d4d  18245960
# 2  8842281e1d1347389f2ab93d60773d4d  32075825
#
#                           review_id  is_read  rating  \
# 0  4443cb6883624c3772625ef5b7b4e138    False       0
# 1  dfdbb7b0eb5a7e4c26d59a937e2e5feb     True       5
# 2  11ffeb4204d7421f716a8f91c190ef2c    False       0
#
#                               review_text_incomplete  \
# 0
# 1  This is a special book. It started slow for ab...
# 2
#
#                        date_added                    date_updated  \
# 0  Fri Sep 08 10:44:24 -0700 2017  Fri Sep 08 10:44:24 -0700 2017
# 1  Sun Jul 30 07:44:10 -0700 2017  Wed Aug 30 00:00:26 -0700 2017
# 2  Wed May 31 06:41:50 -0700 2017  Wed May 31 06:41:51 -0700 2017
#
#                           read_at                      started_at
# 0
# 1  Sat Aug 26 12:05:52 -0700 2017  Tue Aug 15 13:23:18 -0700 2017
# 2

# %%
INTER_COLUMNS_TO_DROP = [
]

# %%
inter_clean = inter_sample.drop(columns=[c for c in INTER_COLUMNS_TO_DROP if c in inter_sample.columns])

# %%
summary_inter_clean = pd.DataFrame({
    'dtype': inter_clean.dtypes.astype(str),
    'non_null': inter_clean.notna().sum(),
    'null_pct': (inter_clean.isna().sum() / len(inter_clean) * 100).round(1),
})
display(summary_inter_clean)
# Out:
#                         dtype  non_null  null_pct
# user_id                   str     10000       0.0
# book_id                   str     10000       0.0
# review_id                 str     10000       0.0
# is_read                  bool     10000       0.0
# rating                  int64     10000       0.0
# review_text_incomplete    str     10000       0.0
# date_added                str     10000       0.0
# date_updated              str     10000       0.0
# read_at                   str     10000       0.0
# started_at                str     10000       0.0

# %%
inter_clean.head(5)
# Out:
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d  19161852
# 1  8842281e1d1347389f2ab93d60773d4d  18245960
# 2  8842281e1d1347389f2ab93d60773d4d  32075825
# 3  8842281e1d1347389f2ab93d60773d4d     43615
# 4  8842281e1d1347389f2ab93d60773d4d  26721984
#
#                           review_id  is_read  rating  \
# 0  4443cb6883624c3772625ef5b7b4e138    False       0
# 1  dfdbb7b0eb5a7e4c26d59a937e2e5feb     True       5
# 2  11ffeb4204d7421f716a8f91c190ef2c    False       0
# 3  07ab7d654e3c84769e5eb8e5cabd5e79    False       0
# 4  90b82c8d8e8a514b5fd1e4568075e052    False       0
#
#                               review_text_incomplete  \
# 0
# 1  This is a special book. It started slow for ab...
# 2
# 3
# 4
#
#                        date_added                    date_updated  \
# 0  Fri Sep 08 10:44:24 -0700 2017  Fri Sep 08 10:44:24 -0700 2017
# 1  Sun Jul 30 07:44:10 -0700 2017  Wed Aug 30 00:00:26 -0700 2017
# 2  Wed May 31 06:41:50 -0700 2017  Wed May 31 06:41:51 -0700 2017
# 3  Mon Apr 03 13:27:29 -0700 2017  Mon Apr 03 13:27:30 -0700 2017
# 4  Wed Mar 29 00:28:30 -0700 2017  Wed Mar 29 00:28:31 -0700 2017
#
#                           read_at                      started_at
# 0
# 1  Sat Aug 26 12:05:52 -0700 2017  Tue Aug 15 13:23:18 -0700 2017
# 2
# 3
# 4

# %%
from src.utils.io import read_jsonl_chunks
import pyarrow as pa
import pyarrow.parquet as pq

INTER_OUTPUT_PATH = OUTPUT_DIR / 'interactions_clean.parquet'
INTER_CHUNKSIZE = 500_000

writer = None
total_rows = 0

for chunk_idx, chunk in enumerate(read_jsonl_chunks(cfg.interactions_file, chunksize=INTER_CHUNKSIZE)):
    chunk = chunk.drop(columns=[c for c in INTER_COLUMNS_TO_DROP if c in chunk.columns])
    total_rows += len(chunk)
    
    table = pa.Table.from_pandas(chunk, preserve_index=False)
    if writer is None:
        writer = pq.ParquetWriter(INTER_OUTPUT_PATH, table.schema, compression='snappy')
    writer.write_table(table)
    
    if chunk_idx % 10 == 0:
        print(f'  Chunk {chunk_idx}: {total_rows:,} rows so far')

if writer:
    writer.close()

print(f'   Total rows: {total_rows:,}')
# Out:
#   Chunk 0: 500,000 rows so far
#   Chunk 10: 5,500,000 rows so far
#   Chunk 20: 10,500,000 rows so far
#   Chunk 30: 15,500,000 rows so far
#   Chunk 40: 20,500,000 rows so far
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 11
#       7
#       8 writer = None
#       9 total_rows = 0
#      10
# ---> 11 for chunk_idx, chunk in enumerate(read_jsonl_chunks(cfg.interactions_file, chunksize=INTER_CHUNKSIZE)):
#      12     chunk = chunk.drop(columns=[c for c in INTER_COLUMNS_TO_DROP if c in chunk.columns])
#      13     total_rows += len(chunk)
#      14
#
# File ~/projects/BigBook/src/utils/io.py:30, in read_jsonl_chunks(path, chunksize)
#      29 def read_jsonl_chunks(path: Path, chunksize: int) -> Iterator[pd.DataFrame]:
# ---> 30     yield from pd.read_json(
#      31         path,
#      32         lines=True,
#      33         compression="gzip",
#      34         chunksize=chunksize,
#      35     )
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/io/json/_json.py:1105, in JsonReader.__next__(self)
#    1103 try:
#    1104     lines_json = self._combine_lines(lines)
# -> 1105     obj = self._get_object_parser(lines_json)
#    1107     # Make sure that the returned objects have the right index.
#    1108     obj.index = range(self.nrows_seen, self.nrows_seen + len(obj))
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/io/json/_json.py:1061, in JsonReader._get_object_parser(self, json)
#    1050 kwargs = {
#    1051     "orient": self.orient,
#    1052     "dtype": self.dtype,
#    (...)   1058     "dtype_backend": self.dtype_backend,
#    1059 }
#    1060 if typ == "frame":
# -> 1061     return FrameParser(json, **kwargs).parse()
#    1062 elif typ == "series":
#    1063     if not isinstance(dtype, bool):
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/io/json/_json.py:1199, in Parser.parse(self)
#    1197 if self.convert_axes:
#    1198     obj = self._convert_axes(obj)
# -> 1199 obj = self._try_convert_types(obj)
#    1200 return obj
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/io/json/_json.py:1437, in FrameParser._try_convert_types(self, obj)
#    1435 arrays = []
#    1436 for col_label, series in obj.items():
# -> 1437     result, _ = self._try_convert_data(
#    1438         col_label,
#    1439         series,
#    1440         convert_dates=_should_convert_dates(
#    1441             self.convert_dates,
#    1442             keep_default_dates=self.keep_default_dates,
#    1443             col=col_label,
#    1444         ),
#    1445     )
#    1446     arrays.append(result.array)
#    1447 return DataFrame._from_arrays(
#    1448     arrays, obj.columns, obj.index, verify_integrity=False
#    1449 )
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/io/json/_json.py:1267, in Parser._try_convert_data(self, name, data, use_dtypes, convert_dates, is_axis)
#    1264                 return data, False
#    1266 if convert_dates:
# -> 1267     new_data = self._try_convert_to_date(data)
#    1268     if new_data is not data:
#    1269         return new_data, True
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/io/json/_json.py:1356, in Parser._try_convert_to_date(self, data)
#    1354 for format in (None, "iso8601", "mixed"):
#    1355     try:
# -> 1356         return to_datetime(new_data, errors="raise", format=format)
#    1357     except Exception:
#    1358         pass
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# --> 254     cache_dates = convert_listlike(unique_dates, format)
#     255     # GH#45319
#     256     try:
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:437, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     434 if format is not None and format != "mixed":
#     435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#     440     yearfirst=yearfirst,
#     441     utc=utc,
#     442     errors=errors,
#     443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#     449     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/pandas/core/arrays/datetimes.py:2623, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2620 # if str-dtype, convert
#    2621 data = np.asarray(data, dtype=np.object_)
# -> 2623 result, tz_parsed = tslib.array_to_datetime(
#    2624     data,
#    2625     errors=errors,
#    2626     utc=utc,
#    2627     dayfirst=dayfirst,
#    2628     yearfirst=yearfirst,
#    2629     creso=abbrev_to_npy_unit(out_unit),
#    2630 )
#    2632 if tz_parsed is not None:
#    2633     # We can take a shortcut since the datetime64 numpy array
#    2634     #  is in UTC
#    2635     return result, tz_parsed
#
# File pandas/_libs/tslib.pyx:259, in pandas._libs.tslib.array_to_datetime()
# --> 259 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslib.pyx:430, in pandas._libs.tslib.array_to_datetime()
# --> 430 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/conversion.pyx:658, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
# --> 658 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/parsing.pyx:321, in pandas._libs.tslibs.parsing.parse_datetime_string()
# --> 321 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/parsing.pyx:646, in pandas._libs.tslibs.parsing.dateutil_parse()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/dateutil/parser/_parser.py:719, in parser._parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     716     yearfirst = info.yearfirst
#     718 res = self._result()
# --> 719 l = _timelex.split(timestr)         # Splits the timestr into tokens
#     721 skipped_idxs = []
#     723 # year/month/day list
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/dateutil/parser/_parser.py:201, in _timelex.split(cls, s)
#     199 @classmethod
#     200 def split(cls, s):
# --> 201     return list(cls(s))
#
# File ~/projects/BigBook/env/lib/python3.12/site-packages/dateutil/parser/_parser.py:189, in _timelex.__next__(self)
#     186 def __iter__(self):
#     187     return self
# --> 189 def __next__(self):
#     190     token = self.get_token()
#     191     if token is None:
#
# KeyboardInterrupt:

# %%
metadata = pq.read_metadata(INTER_OUTPUT_PATH)
print(f'Rows parquet: {metadata.num_rows:,}')
print(f'Columns: {metadata.num_columns}')
print(f'File size: {INTER_OUTPUT_PATH.stat().st_size / 1e6:.1f} MB')

df_check = pd.read_parquet(INTER_OUTPUT_PATH).head(3)
print(f'\nFinal columns ({len(df_check.columns)}):')
print(list(df_check.columns))
display(df_check)
# Out:
# Rows parquet: 55,397,550
# Columns: 10
# File size: 3851.0 MB
#
# Final columns (10):
# ['user_id', 'book_id', 'review_id', 'is_read', 'rating', 'review_text_incomplete', 'date_added', 'date_updated', 'read_at', 'started_at']
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d  19161852
# 1  8842281e1d1347389f2ab93d60773d4d  18245960
# 2  8842281e1d1347389f2ab93d60773d4d  32075825
#
#                           review_id  is_read  rating  \
# 0  4443cb6883624c3772625ef5b7b4e138    False       0
# 1  dfdbb7b0eb5a7e4c26d59a937e2e5feb     True       5
# 2  11ffeb4204d7421f716a8f91c190ef2c    False       0
#
#                               review_text_incomplete  \
# 0
# 1  This is a special book. It started slow for ab...
# 2
#
#                        date_added                    date_updated  \
# 0  Fri Sep 08 10:44:24 -0700 2017  Fri Sep 08 10:44:24 -0700 2017
# 1  Sun Jul 30 07:44:10 -0700 2017  Wed Aug 30 00:00:26 -0700 2017
# 2  Wed May 31 06:41:50 -0700 2017  Wed May 31 06:41:51 -0700 2017
#
#                           read_at                      started_at
# 0
# 1  Sat Aug 26 12:05:52 -0700 2017  Tue Aug 15 13:23:18 -0700 2017
# 2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
